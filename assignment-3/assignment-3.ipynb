# %% [markdown]
# ### Assignment #3 Decision trees with a toy task and the UCI Adult dataset

# %%
import collections
from io import StringIO

import numpy as np
import pandas as pd
import pydotplus  
import seaborn as sns
from ipywidgets import Image
from sklearn import preprocessing
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (10, 8)

# %%
def create_df(dic, feature_list):
    out = pd.DataFrame(dic)
    out = pd.concat([out, pd.get_dummies(out[feature_list])], axis=1)
    out.drop(feature_list, axis=1, inplace=True)
    return out



def intersect_features(train, test):
    common_feat = list(set(train.keys()) & set(test.keys()))
    return train[common_feat], test[common_feat]

# %%
features = ["Looks", "Alcoholic_beverage", "Eloquence", "Money_spent"]

# %%
df_train = {}
df_train["Looks"] = [
    "handsome",
    "handsome",
    "handsome",
    "repulsive",
    "repulsive",
    "repulsive",
    "handsome",
]
df_train["Alcoholic_beverage"] = ["yes", "yes", "no", "no", "yes", "yes", "yes"]
df_train["Eloquence"] = ["high", "low", "average", "average", "low", "high", "average"]
df_train["Money_spent"] = ["lots", "little", "lots", "little", "lots", "lots", "lots"]
df_train["Will_go"] = LabelEncoder().fit_transform(["+", "-", "+", "-", "-", "+", "+"])

df_train = create_df(df_train, features)
df_train
# Out:
#    Will_go  Looks_handsome  Looks_repulsive  Alcoholic_beverage_no  \
# 0        0            True            False                  False
# 1        1            True            False                  False
# 2        0            True            False                   True
# 3        1           False             True                   True
# 4        1           False             True                  False
# 5        0           False             True                  False
# 6        0            True            False                  False
#
#    Alcoholic_beverage_yes  Eloquence_average  Eloquence_high  Eloquence_low  \
# 0                    True              False            True          False
# 1                    True              False           False           True
# 2                   False               True           False          False
# 3                   False               True           False          False
# ...

# %%
df_test = {}
df_test["Looks"] = ["handsome", "handsome", "repulsive"]
df_test["Alcoholic_beverage"] = ["no", "yes", "yes"]
df_test["Eloquence"] = ["average", "high", "average"]
df_test["Money_spent"] = ["lots", "little", "lots"]
df_test = create_df(df_test, features)
df_test
# Out:
#    Looks_handsome  Looks_repulsive  Alcoholic_beverage_no  \
# 0            True            False                   True
# 1            True            False                  False
# 2           False             True                  False
#
#    Alcoholic_beverage_yes  Eloquence_average  Eloquence_high  \
# 0                   False               True           False
# 1                    True              False            True
# 2                    True               True           False
#
#    Money_spent_little  Money_spent_lots
# 0               False              True
# 1                True             False
# 2               False              True

# %%
y = df_train["Will_go"]
df_train, df_test = intersect_features(train=df_train, test=df_test)
df_train
# Out:
#    Looks_handsome  Looks_repulsive  Money_spent_little  Eloquence_high  \
# 0            True            False               False            True
# 1            True            False                True           False
# 2            True            False               False           False
# 3           False             True                True           False
# 4           False             True               False           False
# 5           False             True               False            True
# 6            True            False               False           False
#
#    Alcoholic_beverage_yes  Money_spent_lots  Eloquence_average  \
# 0                    True              True              False
# 1                    True             False              False
# 2                   False              True               True
# 3                   False             False               True
# 4                    True              True              False
# ...

# %%
df_test
# Out:
#    Looks_handsome  Looks_repulsive  Money_spent_little  Eloquence_high  \
# 0            True            False               False           False
# 1            True            False                True            True
# 2           False             True               False           False
#
#    Alcoholic_beverage_yes  Money_spent_lots  Eloquence_average  \
# 0                   False              True               True
# 1                    True             False              False
# 2                    True              True               True
#
#    Alcoholic_beverage_no
# 0                   True
# 1                  False
# 2                  False

# %% [markdown]
# Draw a decision tree (by hand or in any graphics editor) for this dataset. Optionally you can also implement tree construction and draw it here.

# %% [markdown]
# 1. What is the entropy
# S0 of the initial system? By system states, we mean values of the binary feature “Will_go” - 0 or 1 - two states in total.

# %%
def entropy(series):
    proportions = series.value_counts(normalize=True)
    return -np.sum(proportions * np.log2(proportions))

s0 = entropy(y)
print(f"S0: {s0:.4f}")
# Out:
# S0: 0.9852

# %% [markdown]
# 2. Let’s split the data by the feature “Looks_handsome”. What is the entropy S1
#  of the left group - the one with “Looks_handsome”. What is the entropy S2
#  in the opposite group? What is the information gain (IG) if we consider such a split?

# %%
left_group = y[df_train["Looks_handsome"] == 1]
s1 = entropy(left_group)
print(f"S1: {s1:.4f}")

right_group = y[df_train["Looks_handsome"] == 0]
s2 = entropy(right_group)
print(f"S2: {s2:.4f}")

n_total = len(y)
n_left = len(left_group)
n_right = len(right_group)

ig = s0 - (n_left / n_total) * s1 - (n_right / n_total) * s2
print(f"Information Gain: {ig:.4f}")
# Out:
# S1: 0.8113
# S2: 0.9183
# Information Gain: 0.1281

# %% [markdown]
# Train a decision tree using sklearn on the training data. You may choose any depth for the tree.

# %%
clf = DecisionTreeClassifier(
    max_depth=3, random_state=17
)
clf.fit(df_train, y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=17)

# %% [markdown]
# Additional: display the resulting tree using graphviz. You can use pydot or a web-service, e.g. this one.

# %%
plt.figure(figsize=(12, 8))

plot_tree(
    clf,
    feature_names=df_train.columns,
    class_names=["No", "Yes"],
    filled=True,
    rounded=True,
    fontsize=10,
)

plt.show()

# %% [markdown]
# #### Part 2. Functions for calculating entropy and information gain.

# %% [markdown]
# Consider the following warm-up example: we have 9 blue balls and 11 yellow balls. Let ball have label 1 if it is blue, 0 otherwise.

# %%
balls = [1 for i in range(9)] + [0 for i in range(11)]

# %%
# two groups
balls_left = [1 for i in range(8)] + [0 for i in range(5)]  # 8 blue and 5 yellow
balls_right = [1 for i in range(1)] + [0 for i in range(6)]  # 1 blue and 6 yellow

# %% [markdown]
# Implement a function to calculate the Shannon Entropy

# %%
def entropy(a_list):
    proportions = pd.Series(a_list).value_counts(normalize=True)
    return -np.sum(proportions * np.log2(proportions))
    pass

# %% [markdown]
# Tests

# %%
print(entropy(balls))  # 9 blue и 11 yellow
print(entropy(balls_left))  # 8 blue и 5 yellow
print(entropy(balls_right))  # 1 blue и 6 yellow
print(entropy([1, 2, 3, 4, 5, 6]))  # entropy of a fair 6-sided die
# Out:
# 0.9927744539878083
# 0.9612366047228759
# 0.5916727785823275
# 2.584962500721156

# %% [markdown]
# 3. What is the entropy of the state given by the list balls_left?
# 4. What is the entropy of a fair die? (where we look at a die as a system with 6 equally probable states)?

# %%
# information gain calculation
def information_gain(root, left, right):
    """ root - initial data, left and right - two partitions of initial data"""
    n_total = len(root)
    n_left = len(left)
    n_right = len(right)

    s_root = entropy(root)
    s_left = entropy(left)
    s_right = entropy(right)

    ig = s_root - (n_left / n_total) * s_left - (n_right / n_total) * s_right

    return ig
    pass

# %% [markdown]
# 5. What is the information gain from splitting the initial dataset into balls_left and balls_right ?

# %%
# 1. Verileri ham haliyle yeniden yüklüyoruz
DATA_PATH = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"
data_train = pd.read_csv(DATA_PATH + "adult_train.csv", sep=";")
data_test = pd.read_csv(DATA_PATH + "adult_test.csv", sep=";")

# 2. Test verisindeki hatalı etiketli satırları temizliyoruz
data_test = data_test[
    (data_test["Target"] == " >50K.") | (data_test["Target"] == " <=50K.")
]

# 3. Target değişkenini güvenli bir şekilde sayıya çeviriyoruz (nokta ve boşlukları arındırarak)
data_train["Target"] = (
    data_train["Target"].astype(str).str.strip().map({"<=50K": 0, ">50K": 1})
)
data_test["Target"] = (
    data_test["Target"]
    .astype(str)
    .str.strip()
    .map({"<=50K.": 0, ">50K.": 1})
)

# Kontrol edelim
print("Train shape:", data_train.shape)
print("Test shape:", data_test.shape)
# Out:
# Train shape: (32561, 15)
# Test shape: (16281, 15)

# %%
data_test["Country_ Holand-Netherlands"] = 0

# %%
set(data_train.columns) - set(data_test.columns)
# Out:
# set()

# %%
data_train.head(2)
# Out:
#    Age          Workclass  fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         Martial_Status        Occupation    Relationship    Race    Sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    Capital_Gain  Capital_Loss  Hours_per_week         Country  Target
# 0          2174             0              40   United-States       0
# 1             0             0              13   United-States       0

# %%
data_test.head(2)
# Out:
#   Age Workclass    fnlwgt Education  Education_Num       Martial_Status  \
# 1  25   Private  226802.0      11th            7.0        Never-married
# 2  38   Private   89814.0   HS-grad            9.0   Married-civ-spouse
#
#            Occupation Relationship    Race    Sex  Capital_Gain  Capital_Loss  \
# 1   Machine-op-inspct    Own-child   Black   Male           0.0           0.0
# 2     Farming-fishing      Husband   White   Male           0.0           0.0
#
#    Hours_per_week         Country  Target  Country_ Holand-Netherlands
# 1            40.0   United-States       0                            0
# 2            50.0   United-States       0                            0

# %%
X_train = data_train
X_test = data_test

# %% [markdown]
# 3.1 Decision tree without parameter tuning

# %%
tree = DecisionTreeClassifier(max_depth=3, random_state=17)

# %%
# 1. Kategorik sütunları One-Hot Encoding ile sayısallaştırıyoruz
# (Target sütununu ve bağımsız değişkenleri karıştırmamak için önce X ve y'yi ayıralım)
X_train = data_train.drop(columns=["Target"])
y_train = data_train["Target"]

X_test = data_test.drop(columns=["Target"])
y_test = data_test["Target"]

# 2. get_dummies ile metinleri sayısal sütunlara çeviriyoruz
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# 3. Train ve Test setindeki sütunların birebir aynı olmasını sağlıyoruz (eksik sütun çakışmasını önlemek için)
X_train, X_test = X_train.align(X_test, join="left", axis=1, fill_value=0)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=17)

# %%
tree_predictions = tree.predict(X_test)

# %%
acc = accuracy_score(y_test, tree_predictions)
print(f'Decision Tree Acc: {acc:.4f}')
# Out:
# Decision Tree Acc: 0.8361

# %% [markdown]
# 3.2 Decision tree with parameter tuning

# %%
tree = DecisionTreeClassifier(random_state=17)
tree_params = {"max_depth": range(2, 11)}

# %%
locally_best_tree = GridSearchCV(
    estimator=tree, param_grid=tree_params, cv=5, scoring="accuracy"
)

# %%
locally_best_tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=17),
#              param_grid={'max_depth': range(2, 11)}, scoring='accuracy')

# %%
tuned_tree = DecisionTreeClassifier(max_depth=9, random_state=17)
tuned_tree.fit(X_train, y_train)
tuned_tree_predictions = tuned_tree.predict(X_test)
tuned_accuracy = accuracy_score(y_test, tuned_tree_predictions)
print(f"Tuned Decision Tree Accuracy: {tuned_accuracy:.4f}")
# Out:
# Tuned Decision Tree Accuracy: 0.8087
